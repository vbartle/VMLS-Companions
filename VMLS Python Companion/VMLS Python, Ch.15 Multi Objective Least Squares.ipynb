       [0.022],
       [0.031],
       [0.046],
       [0.051],
       [0.057],
       [0.056],
       [0.041],
       [0.034],
       [0.028],
       [0.024],
       [0.02 ],
       [0.018],
       [0.017],
       [0.017],
       [0.014],
       [0.011],
       [0.008],
       [0.011],
       [0.009],
       [  np.nan],
       [0.003],
       [0.007],
       [0.016],
       [0.027],
       [0.033],
       [0.039],
       [0.054],
       [0.062],
       [0.07 ],
       [0.065],
       [0.064],
       [0.058],
       [0.046],
       [0.038],
       [0.024],
       [0.023],
       [0.022],
       [0.018],
       [0.014],
       [0.013],
       [0.009],
       [0.009],
       [  np.nan],
       [  np.nan],
       [0.007],
       [0.012],
       [0.021],
       [0.033],
       [0.049],
       [0.065],
       [0.079],
       [0.084],
       [0.078],
       [0.077],
       [0.068],
       [0.059],
       [0.05 ],
       [0.038],
       [0.03 ],
       [0.03 ],
       [0.032],
       [0.024],
       [0.021],
       [0.02 ],
       [0.017],
       [0.016],
       [  np.nan],
       [  np.nan],
       [0.008],
       [0.01 ],
       [0.013],
       [0.013],
       [0.014],
       [0.014],
       [0.019],
       [0.026],
       [0.032],
       [0.038],
       [0.038],
       [0.04 ],
       [0.031],
       [0.03 ],
       [0.026],
       [0.026],
       [0.023],
       [0.016],
       [0.014]])

# %% [markdown]
# # 15.1 Multi-Objective Least Squares

# %%
def mols_solve(As,bs,lambdas):
    k = len(lambdas)
    Atil = np.vstack(np.sqrt(lambdas[i])*As[i] for i in range(k))
    btil = np.hstack(np.sqrt(lambdas[i])*bs[i] for i in range(k)).ravel() #ravel quick fix for shape compatibility
    return npl.lstsq(Atil,btil)[0]

# %%
As = np.array([np.random.randn(10,5),np.random.randn(10,5)])
bs = np.array([np.random.randn(10),np.random.randn(10)])

# %%
N = 200
lambdas = 10**np.linspace(-4,4,200)
x,J1,J2 = np.zeros((5,N)), np.zeros(N), np.zeros(N)
for k in range(N):
    x[:,k] = mols_solve(As,bs,[1,lambdas[k]])
    J1[k] = np.square(npl.norm(np.matmul(As[0],x[:,k]) - bs[0]))
    J2[k] = np.square(npl.norm(np.matmul(As[1],x[:,k]) - bs[1]))
# Out:
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   after removing the cwd from sys.path.
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """

# %%
plt.plot(lambdas,x.T)
plt.xscale('log')
# Out:
# [<matplotlib.lines.Line2D at 0x7f7f95ef1cc0>,
#  <matplotlib.lines.Line2D at 0x7f7f95ef1ef0>,
#  <matplotlib.lines.Line2D at 0x7f7f95f0b080>,
#  <matplotlib.lines.Line2D at 0x7f7f95f0b1d0>,
#  <matplotlib.lines.Line2D at 0x7f7f95f0b320>]

# %% [markdown]
# wow

# %%
plt.plot(lambdas,J1)
plt.plot(lambdas,J2)
plt.xscale('log')

# %%
plt.plot(J1,J2)

# %% [markdown]
# # 15.2, 3 Control, Estimation and Inversion

# %%
#estimating a periodic time series 
np.shape(ozone)
k = 14
N=k*24
plt.plot(range(N),ozone, marker= 'o')
plt.yscale('log')
# Out:
# (336, 1)

# %%
#recall mols solve from above:
def mols_solve(As,bs,lambdas):
    k = len(lambdas)
    Atil = np.vstack(np.sqrt(lambdas[i])*As[i] for i in range(k))
    btil = np.hstack(np.sqrt(lambdas[i])*bs[i] for i in range(k)).ravel()
    return npl.lstsq(Atil,btil)[0]
#     return lambdas,bs, Atil, btil

# %%
k = 14
N=k*24
A = np.vstack(np.eye(24) for i in range(k))
D = -np.eye(24) + np.hstack([np.vstack([np.zeros((23,1)),1]),np.vstack([np.eye(23),np.zeros((1,23))])])
ind = np.array([k for k in range(0,len(ozone)) if not np.isnan(ozone[k])])
As = np.array([A[ind,:],D])
bs = np.array([np.log(ozone[ind]).ravel(), np.zeros(24)])
x = mols_solve(As,bs,[1,1])
x
# Out:
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   after removing the cwd from sys.path.
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   """
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# array([-4.47169601, -4.6155201 , -4.66369591, -4.92445728, -4.92485585,
#        -4.92525443, -4.57013665, -4.18860317, -3.78897573, -3.47443415,
#        -3.18300288, -2.94105468, -2.75587987, -2.66758968, -2.66077992,
#        -2.74500243, -2.90490121, -3.09433721, -3.3102847 , -3.55996092,
#        -3.75306083, -3.95428572, -4.23270891, -4.33879988])

# %%
plt.scatter(range(N), ozone)
plt.yscale("log")
plt.plot(range(N), np.vstack(np.array([np.exp(x) for i in range(k)]).ravel()), color="orange")

# %%
x = mols_solve(As,bs,[1,100])
plt.scatter(range(N),ozone)
plt.yscale('log')
plt.plot(range(N), np.vstack(np.array([np.exp(x) for i in range(k)]).ravel()), color="orange")
# Out:
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   after removing the cwd from sys.path.
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   """
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %% [markdown]
# # 15.4 Regularized Data Fitting

# %%
D = {'ytest': np.array([-1.05772   ,  0.879117  ,  1.98136   ,  0.867012  ,  2.1365    ,
       -0.701948  ,  0.941469  ,  1.49755   ,  0.550205  ,  1.34245   ,
        1.21445   ,  0.00449111,  0.957535  ,  0.077864  ,  1.73558   ,
       -0.325244  ,  2.56555   ,  1.10081   ,  2.70644   , -1.10049   ]), 'xtest': np.array([0.396674, 0.777517, 0.1184  , 0.223266, 0.901463, 0.358033,
       0.260402, 0.804281, 0.631664, 0.149704, 0.551333, 0.663999,
       0.164948, 0.651698, 0.123026, 0.337066, 0.083208, 0.204422,
       0.978   , 0.403676]), 'xtrain': np.array([0.10683, 0.25578, 0.27112, 0.30299, 0.50204, 0.65845, 0.68423,
       0.70259, 0.73406, 0.94035]), 'ytrain': np.array([ 1.82422  ,  0.813549 ,  0.92406  ,  0.42067  ,  0.446178 ,
       -0.0373407, -0.210935 , -0.103327 ,  0.332097 ,  2.29278  ])}
xtrain,ytrain,xtest,ytest = D["xtrain"],D["ytrain"],D["xtest"],D["ytest"]

# %%
N = len(ytrain)
Ntest = len(ytest)
p=5
omega = np.array([13.69,3.55,23.25,6.03])
phi = np.array([.21,.02,-1.87,1.72])
a = np.vstack(xtrain) * omega.T #J: xtrain*omega', where xtrain is default vstacked
b = np.ones((N,1)) * phi.T #where in J ones(N) is in N,1 form by default
A = np.hstack([np.ones((N,1)),np.sin(a+b)])
Atest = np.hstack([np.ones((Ntest,1)), np.sin((np.vstack(xtest)*omega.T) + (np.ones((Ntest,1))*phi.T))])
npts = 100
lambdas = 10**np.linspace(-6,6,npts)
err_train = np.zeros((npts,1))
err_test = np.zeros((npts,1))
thetas = np.zeros((p,npts))

# %%
#recall mols solve from above:
def mols_solve(As,bs,lambdas):
    k = len(lambdas)
    Atil = np.vstack(np.sqrt(lambdas[i])*As[i] for i in range(k))
    btil = np.hstack(np.sqrt(lambdas[i])*bs[i] for i in range(k)).ravel()
    return npl.lstsq(Atil,btil)[0]

#recall rms:
rms = lambda x:np.sqrt(np.mean(np.square(x)))
As = np.array([A, np.hstack([np.zeros((p-1,1)), np.eye(p-1)])])
bs = np.array([np.hstack(ytrain), np.zeros(p-1)])

for k in range(npts):
    theta = mols_solve(
        As,
        bs, 
        np.array([1, lambdas[k]])
    )
    
    err_train[k] = rms(ytrain - np.matmul(A,theta))
    err_test[k] = rms(ytest - np.matmul(Atest,theta))
    thetas[:,k] = theta
# Out:
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   after removing the cwd from sys.path.
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   """
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
plt.plot(lambdas,err_train)
plt.plot(lambdas,err_test)
plt.xscale('log')

# %%
plt.plot(lambdas,thetas.T)
plt.xscale('log')
# Out:
# [<matplotlib.lines.Line2D at 0x7f7f9005f9e8>,
#  <matplotlib.lines.Line2D at 0x7f7f9005fb70>,
#  <matplotlib.lines.Line2D at 0x7f7f9005fcc0>,
#  <matplotlib.lines.Line2D at 0x7f7f9005fe10>,
#  <matplotlib.lines.Line2D at 0x7f7f9005ff60>]

# %% [markdown]
# # 15.5 Complexity

# %%
m,n = 100,5000
A = np.random.randn(m,n)
b = np.random.randn(m)
xdes = np.random.randn(n)
lam = 2.0
# %timeit xhat1 = npl.lstsq(np.vstack([A, np.sqrt(lam)*np.eye(n)]), np.block([b, np.sqrt(lam)*xdes]))[0]
##this takes excessively long, might want to look into what's causing it to lag so much
# Out:
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.
# 51.1 s ± 2.03 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
Q,R = npl.qr(np.vstack([A.T,np.sqrt(lam)*np.eye(m)]))
xhat2 = A.T * npl.lstsq(R,npl.lstsq(R.T, b-np.matmul(A,xdes))[0])[0] + np.vstack(xdes)
# Out:
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# 31.7 ms ± 6.26 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
xhat1 = npl.lstsq(np.vstack([A, np.sqrt(lam)*np.eye(n)]), np.block([b, np.sqrt(lam)*xdes]))[0]
xhat2 = A.T * npl.lstsq(R,npl.lstsq(R.T, b-np.matmul(A,xdes))[0])[0] + np.vstack(xdes)

npl.norm(xhat1-xhat2)
# Out:
# /home/linbo/anaconda3/envs/nlu/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c4d3de587375> in <module>
#       1 xhat1 = npl.lstsq(np.vstack([A, np.sqrt(lam)*np.eye(n)]), np.block([b, np.sqrt(lam)*xdes]))[0]
# ----> 2 xhat2 = A.T * npl.lstsq(R,npl.lstsq(R.T, b-np.matmul(A,xdes))[0])[0] + np.vstack(xdes)
#       3
#       4 npl.norm(xhat1-xhat2)
#
# NameError: name 'R' is not defined
